# %% [markdown]
# <a href="https://colab.research.google.com/github/abbylin20070529-source/prog/blob/main/D2_%E5%AE%B9%E5%99%A8%E8%AE%8A%E6%95%B8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a=1

# %%
type(a)
# Out:
# int

# %%
print(a)
# Out:
# 1

# %%
b='abc'

# %%
type(b)
# Out:
# str

# %%
print(b)
# Out:
# abc

# %%
c=input('請輸入變數c')
# Out:
# 請輸入變數cabcde

# %%
type(c)
# Out:
# str

# %%
rooms={ 1:'Foyer', 2:'Conference Room'}

# %%
type(rooms)
# Out:
# dict

# %%
rooms[1]
# Out:
# 'Foyer'

# %%
rooms = { 1:'Foyer', 2:'Conference Room'}

# %%
rooms[1]
# Out:
# 'Foyer'

# %%
rooms={ 1:'Foyer', 2:'Conference Room'}

# %%
room=input('Enter the room number: ')
# Out:
# Enter the room number: 1

# %%
room
# Out:
# '1'

# %%
rooms[int(room)]
# Out:
# 'Foyer'
